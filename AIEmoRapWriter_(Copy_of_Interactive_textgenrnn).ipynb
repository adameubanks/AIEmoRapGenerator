# %% [markdown]
# <a href="https://colab.research.google.com/github/KhanradCoder/AIEmoRapGenerator/blob/master/AIEmoRapWriter_(Copy_of_Interactive_textgenrnn).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  Interactive textgenrnn Demo w/ GPU
#
# by [Max Woolf](http://minimaxir.com)
#
# *Last updated: December 2nd, 2018*
#
# Generate text using a pretrained neural network with a few lines of code, or easily train your own text-generating neural network of any size and complexity, **for free on a GPU using Collaboratory!**
#
# For more about textgenrnn, you can visit [this GitHub repository](https://github.com/minimaxir/textgenrnn).
#
#
# To get started:
#
# 1. Copy this notebook to your Google Drive to keep it and save your changes.
# 2. Make sure you're running the notebook in Google Chrome.
# 3. Run the cells below:

# %%
# !pip install -q textgenrnn
from google.colab import files
from textgenrnn import textgenrnn
from datetime import datetime
import os

# %% [markdown]
# Set the textgenrnn model configuration here: the default parameters here give good results for most workflows. (see the [demo notebook](https://github.com/minimaxir/textgenrnn/blob/master/docs/textgenrnn-demo.ipynb) for more information about these parameters)
#
# If you are using an input file where documents are line-delimited, make sure to set `line_delimited` to `True`.

# %%
model_cfg = {
    'word_level': False,   # set to True if want to train a word-level model (requires more data and smaller max_length)
    'rnn_size': 128,   # number of LSTM cells of each layer (128/256 recommended)
    'rnn_layers': 3,   # number of LSTM layers (>=2 recommended)
    'rnn_bidirectional': False,   # consider text both forwards and backward, can give a training boost
    'max_length': 30,   # number of tokens to consider before predicting the next (20-40 for characters, 5-10 for words recommended)
    'max_words': 10000,   # maximum number of words to model; the rest will be ignored (word-level model only)
}

train_cfg = {
    'line_delimited': False,   # set to True if each text has its own line in the source file
    'num_epochs': 20,   # set higher to train the model for longer
    'gen_epochs': 5,   # generates sample text from model after given number of epochs
    'train_size': 0.8,   # proportion of input data to train on: setting < 1.0 limits model from learning perfectly
    'dropout': 0.0,   # ignore a random proportion of source tokens each epoch, allowing model to generalize better
    'validation': False,   # If train__size < 1.0, test on holdout dataset; will make overall training slower
    'is_csv': False   # set to True if file is a CSV exported from Excel/BigQuery/pandas
}

# %% [markdown]
# In the Colaboratory Notebook sidebar on the left of the screen, select *Files*. From there you can upload files:
#
# ![alt text](https://i.imgur.com/TGcZT4h.png)
#
# Upload **any text file** and update the file name in the cell below, then run the cell.

# %%
file_name = "lyrics.txt"
model_name = 'aiemorapwriter'   # change to set file name of resulting trained models/texts

# %% [markdown]
# The next cell will start the actual training. And thanks to the power of Keras's CuDNN layers, training is super-fast when compared to CPU training on a local machine!
#
# Ideally, you want a training loss less than `1.0` in order for the model to create sensible text consistently.

# %%
textgen = textgenrnn(name=model_name)

train_function = textgen.train_from_file if train_cfg['line_delimited'] else textgen.train_from_largetext_file

train_function(
    file_path=file_name,
    new_model=True,
    num_epochs=train_cfg['num_epochs'],
    gen_epochs=train_cfg['gen_epochs'],
    batch_size=1024,
    train_size=train_cfg['train_size'],
    dropout=train_cfg['dropout'],
    validation=train_cfg['validation'],
    is_csv=train_cfg['is_csv'],
    rnn_layers=model_cfg['rnn_layers'],
    rnn_size=model_cfg['rnn_size'],
    rnn_bidirectional=model_cfg['rnn_bidirectional'],
    max_length=model_cfg['max_length'],
    dim_embeddings=100,
    word_level=model_cfg['word_level'])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.
#
# Training new model w/ 3-layer, 128-cell LSTMs
# Training on 758,457 character sequences.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/20
# 740/740 [==============================] - 50s 67ms/step - loss: 3.2347
# Epoch 2/20
# 740/740 [==============================] - 44s 59ms/step - loss: 2.8045
# Epoch 3/20
# 740/740 [==============================] - 44s 60ms/step - loss: 1.6390
# Epoch 4/20
# 740/740 [==============================] - 45s 61ms/step - loss: 1.4399
# Epoch 5/20
# 740/740 [==============================] - 46s 62ms/step - loss: 1.3401
# ####################
# Temperature: 0.2
# ####################
#  loose so I don't wanna fuck with me
# I got a fuck nigga start to the drugs to the pain of the pain to me
# I know you can't feel like a savage
# I told me a sandas, I need to take a start
# I say I feel like a nigga shoot it
# I don't wanna die in the club with the pain
# I don't wanna die in the club with th
#
#  the stars
# I don't wanna die in the cut in the cut that I can't say you shoot you that I feel like a boy (yeah)
# I can see you call it me
# I don't wanna die in the pain of the pain
# I know that you say that I say and she gon' stay and she gon' stay at the stars
# I don't wanna die in the dark and the way
#
# on't wanna die in the moonlight
# I don't wanna fuck with the day and they can't say it
# I don't wanna die in the moonlight
# I won't let it
#
# I was too much to the pain and I can say that I don't wanna ever say and I can't say and that I was so what you want to talk about the pain
# I was like a nigga star
#
# ####################
# Temperature: 0.5
# ####################
# a but it's a different good alive
# I know that I be some boost
# I spent a bitch, that I can get so shit
# I pull up on your eyes face through the strug that I ain't never ever are scared out the princess
#
# [Lil Peep:]
# I don't got no one that it's all that I was the gettin' for my head
# They was the face
# I
#
# tartin' shit you hate the fuckin' drugs
#
# I'm a right now
# I can't feel like a hoe, baby, yeah
# I don't wanna fuck with the door
# I got a couple of the percher, that she was the paron time
# Got the was that you lookin'
#
# I got my head, ayy
#
# I was gonna cause I love it
#
#
# I don't wanna put it all of the str
#
#  all on my head
# I say that I told you down to my niggas
# I was heart started to falt
# Bitch I am up, here you want to take it off
# Baby I don't want this shit comperans
# And these heart the pain I won't let a magies
# I put my waist to come down the morning so so gassed up
# I got a fuck with your soul, I s
#
# ####################
# Temperature: 1.0
# ####################
#  ain't be with the backpluped
# But that Hit-jair
# Popes on the things again
# I'm pistions, Roke
# Boke, she don't know what's just heaven rlub? Yallin' Want to Loodrass, I was choking for that gangs truth me to do you can need a face
# (Get on my Morty you-druff)
# Not her inside
# You got eves when you can se
#
# o Panny
# Money I was Surpin'
# My truestous around
# Now I lear you wanna lie like a cuff
# And wrote was hard 'em you ementer, yeah
#
#
# It's a reason too many reals nother damn I ain't gon' gotta vemorice rounds
# I'll start a rockstat, aye, your shit belts, without a quttiping
# Phone boy dead already is eat your one-
# Drugs ksep a secret, fall, fake, scrarce
# You're faded my life feel That Hay Runbr)
#
# Ooh
#
# Drugs don't feel the pain no more, I'm gettin' bruh, lets a chance
# Last till I see your demons s
#
# sa
# Dove, rich, fuck your head
# She ain't aframted she gon' do it, my gun and tell these niggas, uh
# 50 on the Preces from vanfitting [?]
# Raring the [?]
#
# She told me leave that got on throulhtesides we're out
# GothboiClight on the safe, shake 'em at me and the nasion
# Im makin' my voolar all that much th
#
# Epoch 16/20
# 740/740 [==============================] - 43s 59ms/step - loss: 0.8436
# Epoch 17/20
# 740/740 [==============================] - 45s 61ms/step - loss: 0.8129
# Epoch 18/20
# 740/740 [==============================] - 44s 60ms/step - loss: 0.7844
# Epoch 19/20
# 740/740 [==============================] - 46s 62ms/step - loss: 0.7576
# Epoch 20/20
# 740/740 [==============================] - 45s 61ms/step - loss: 0.7340
# ####################
# Temperature: 0.2
# ####################
#  fuck the pen
# I got a new Benz, I just want the money and I got the pistol the pope
# I just wanna hear you can feel it in the room
# And I could fuck yo bitch slippin'
# I can see the same is a man brak (Skrt)
#
#
# You know I wanna see you a new day
#
#
# Who am I, someone that's afraid to let go, uh
# I'm so gas
#
# e club
# I'm so high that I can't feel my
# I could never love her, I don't feel the pain no more
# No more gone, let me hold my niggas
# I don't give a fuck about anything
# I don't know, no feeling like the end of the shit they see it out
# Really hit the dope my crime, I'm with the shit that you don't even k
#
# ke
# I hate everybody in my hometown
# I will not rewind her that I say "what you want her)
# I don't wanna lose you open
# The way I feel at the time to death
# I want the best boy, I don't give a fuck
# Red drop cups, I got their styrofoam
# But I am the best to where the street the face they won't have no frie
#
# ####################
# Temperature: 0.5
# ####################
# th the green like I was the least
# But I still wonder what I'm looking at the toold
# I'm a loner, but I'm not the one, I'ma shoot you in your eyes
# They said her times and the tears and her pussy there
# Everyday it feels like you hold me close
# I've been through alone or the chain
# She told me that she pu
#
# ar
# Could you want your song
# I wrote with your eyes closed
# I know that you wanna ride all in the back of the club without a couple of get smoke on your ass and then we gon' be alone to me
#
# I would blow my brothers subleide
# I just want a new Benz, I'm a rockstar
# I put that pretty consting to the chose
#
#  the devil was in the way
# If I could save you, I was gonna blind
# Always playin' with me
# I told her when I wanna die alone
# Who know what I be on
# Who know what I be on
# Who know what we be on
# The woll of the road, I got the pills for the pain
# She suck my dick so big bitches white is just me a sad sheep
#
# ####################
# Temperature: 1.0
# ####################
#  means, she love me
# But I still ballin' my brothers
# Any jack for some snorp
# You lefin' enemshoes, money and the end of the next once
# Cow my day it's Jonely
# Fuck a bean, yeah
# I'm an anotherreh, buffea really like a Mazs, yeah, I do that little bitch?
# Huh
# Molly in my brains are the same
# If these bruic
#
# arly
# Huh, feel like in your skin (Gang)
# By- comin' too, make my way, won't hell
# Another brain but man, mirror on the walk
# Bitch I'm gone, I'mma keep it from fed
# Now you callin' me call me the same
# You best gotta miss her
#
# What money when the lights girl
# Now that's okay cool Himen, in a commenited so
#
# ound rings like a pool, tope the Paranitacon
# Fuck you in the back then
# You gon' be help meed
# I'm a rockstar
# And crack I love so I could forget you
# I know that you love that (Whoa! You could fuck yo bitch)
# Un, long way, make you fuck with four?
# My niggas is nothin'?
# You shine-tay I too talking to me

# %% [markdown]
# You can download a large amount of generated text from your model with the cell below! Rerun the cell as many times as you want for even more text!

# %%
# this temperature schedule cycles between 1 very unexpected token, 1 unexpected token, 2 expected tokens, repeat.
# changing the temperature schedule can result in wildly different output!
temperature = [1.0, 0.5, 0.2, 0.2]   
prefix = None   # if you want each generated text to start with a given seed text

if train_cfg['line_delimited']:
  n = 1000
  max_gen_length = 60 if model_cfg['word_level'] else 300
else:
  n = 1
  max_gen_length = 2000 if model_cfg['word_level'] else 10000
  
timestring = datetime.now().strftime('%Y%m%d_%H%M%S')
gen_file = '{}_gentext_{}.txt'.format(model_name, timestring)

textgen.generate_to_file(gen_file,
                         temperature=temperature,
                         prefix=prefix,
                         n=n,
                         max_gen_length=max_gen_length)
files.download(gen_file)

# %% [markdown]
# You can download the weights and configuration files in the cell below, allowing you recreate the model on your own computer!

# %%
files.download('{}_weights.hdf5'.format(model_name))
files.download('{}_vocab.json'.format(model_name))
files.download('{}_config.json'.format(model_name))

# %%
from textgenrnn import textgenrnn
textgen = textgenrnn(weights_path='aiemorapwriter_weights.hdf5',
                       vocab_path='aiemorapwriter_vocab.json',
                       config_path='aiemorapwriter_config.json')
for i in range(10):
  textgen.generate_samples(max_gen_length=10000)
  textgen.generate_to_file('aiemorap'+str(i)+'.txt', max_gen_length=10000)

# %% [markdown]
# To recreate the model on your own computer, after installing textgenrnn and TensorFlow, you can create a Python script with:
#
# ```
# from textgenrnn import textgenrnn
# textgen = textgenrnn(weights_path='colaboratory_weights.hdf5',
#                        vocab_path='colaboratory_vocab.json',
#                        config_path='colaboratory_config.json')
#
# textgen.generate_samples(max_gen_length=1000)
# textgen.generate_to_file('textgenrnn_texts.txt', max_gen_length=1000)
# ```
#
# Have fun with your new model! :)

# %% [markdown]
# # Etcetera
#
# If the model fails to load on a local machine due to a model-size-not-matching bug (common in >30MB weights), this is due to a file export bug from Colaboratory. To work around this issue, save the weights to Google Drive with the two cells below and download from there.

# %%
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from google.colab import files
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
uploaded = drive.CreateFile({'title': '{}_weights.hdf5'.format(model_name)})
uploaded.SetContentFile('{}_weights.hdf5'.format(model_name))
uploaded.Upload()
print('Uploaded file with ID {}'.format(uploaded.get('id')))
# Out:
# Uploaded file with ID 1b6T6M32YnXs-c0NB-PEi6MhAdCuG7RHy

# %% [markdown]
# If the notebook has errors (e.g. GPU Sync Fail), force-kill the Colaboratory virtual machine and restart it with the command below:

# %%
# !kill -9 -1
